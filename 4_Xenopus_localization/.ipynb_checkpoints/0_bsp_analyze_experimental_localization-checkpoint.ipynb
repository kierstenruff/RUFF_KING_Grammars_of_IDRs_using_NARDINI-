# %% [markdown]
# # Part 0: Load in libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sbn
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
import re
import math
import scipy
from scipy.stats import ks_2samp
from matplotlib.patches import Rectangle
import pathlib
from matplotlib import font_manager
from scipy.stats import fisher_exact
import localcider
from localcider.sequenceParameters import SequenceParameters
from statannot import add_stat_annotation


# Setup the fonts
fonts_path = pathlib.Path.home().joinpath('fonts') # i.e. `~/fonts` (update as needed)
font_filename = 'ARIAL.TTF'
font_path = fonts_path.joinpath(font_filename)
print(font_path)

font_manager.fontManager.addfont(str(font_path))
prop = font_manager.FontProperties(fname=font_path)

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()
plt.rcParams['pdf.fonttype'] = 42 # Makes text editiable
plt.rcParams['ps.fonttype'] = 42

COLOR_MAP = dict()
COLOR_MAP['A']         = '#8c8c8c'
COLOR_MAP['CHNQST']    = '#077a15'
COLOR_MAP['DE']        = '#e23a36'
COLOR_MAP['FWY']       = '#f58220'
COLOR_MAP['G']         = '#86bd8d'
COLOR_MAP['ILMV']      = '#231f20'
COLOR_MAP['KR']        = '#1725c2'
COLOR_MAP['P']         = '#c25fc9'


# Using the global color map, we convert the colormap of amino acid
# groups, to a map against individual amino acids. This
# serves as our internal color map which is used for styling.
aacolor_map=dict()
for amino_acids in COLOR_MAP:
    for amino_acid in amino_acids:
        aacolor_map[amino_acid] = COLOR_MAP[amino_acids]
# Out:
# /home/research/kiersten.ruff/fonts/ARIAL.TTF

# %% [markdown]
# # Part 1: Load in Data

# %% [markdown]
# ## 1.1 - Load in experimental data

# %%
dfnuc=pd.read_excel('data/PC_Nucleolus_and_NS.xlsx',sheet_name='Compiled_Nucleolus')
#dfloc=dfloc.fillna('')
myconstructs=dfnuc.columns.tolist()

print(dfnuc)
print(myconstructs)

dfnuc_noGPATCH3=dfnuc.drop(columns=['GFP_Gpatch_pMK226','GFP_GPatch4_pMK232'])
print(dfnuc_noGPATCH3)

index_sort = dfnuc_noGPATCH3.median().sort_values().index
sorted_feats=index_sort.tolist()
dfnuc_noGPATCH3 = dfnuc_noGPATCH3[index_sort]

gfpmed=np.nanmedian(dfnuc_noGPATCH3['GFP_Nucleolus'].tolist())
plt.figure(figsize=(5,3))
plt.plot([-1,len(myconstructs)+1],[gfpmed,gfpmed],'--',color='#000000')
sbn.boxplot(dfnuc_noGPATCH3,palette='Greens',showfliers=False)
sbn.stripplot(dfnuc_noGPATCH3,color='#dddddd',size=5,linewidth=1, edgecolor='black', alpha=0.75)
plt.ylabel('Nucleolus Partition Coefficient')
plt.title('Proteins that House Cluster 23 IDRs')
plt.xticks(rotation=90) 

#plt.savefig('exp_localization/figures/cluster_23_nucleolus_PC.pdf', transparent=True, bbox_inches = "tight")

plt.figure(figsize=(5,3))
df_melted = pd.melt(dfnuc_noGPATCH3, var_name='Protein', value_name='PC')
df_melted=df_melted.dropna()
print(df_melted)
ax=sbn.boxplot(data=df_melted, x='Protein', y='PC',palette='Greens',showfliers=False)
sbn.stripplot(data=df_melted, x='Protein', y='PC',color='#dddddd',size=5,linewidth=1, edgecolor='black', alpha=0.75)
plt.plot([0,4],[gfpmed,gfpmed],'--',color='#000000')
add_stat_annotation(ax, data=df_melted, x='Protein', y='PC', \
                    box_pairs=[(('GFP_Nucleolus', 'GFP_BRD7_pMK229')), \
                    (('GFP_Nucleolus', 'GFP_NKAPD1_pMK223')), \
                    (('GFP_Nucleolus', 'GFP_FCF1_pMK230')), \
                    (('GFP_Nucleolus', 'GFP_RP9_pMK224'))], \
                    test='Mann-Whitney', text_format='star', loc='inside', verbose=2)
plt.ylabel('Nucleolus Partition Coefficient')
plt.title('Proteins that House Cluster 23 IDRs')
plt.xticks(rotation=90) 
#plt.savefig('../../exp_localization/figures/cluster_23_nucleolus_PC_w_stats.pdf', transparent=True, bbox_inches = "tight")

from scipy.stats import mannwhitneyu
plist=['GFP_BRD7_pMK229','GFP_NKAPD1_pMK223','GFP_FCF1_pMK230','GFP_RP9_pMK224']
for i in range(0,len(plist)):
    print(mannwhitneyu(dfnuc_noGPATCH3['GFP_Nucleolus'].dropna(),dfnuc_noGPATCH3[plist[i]].dropna()))
# Out:
#     GFP_Nucleolus  GFP_Gpatch_pMK226  GFP_NKAPD1_pMK223  GFP_RP9_pMK224  \
# 0        0.617920           0.843088           2.007163        3.690067
# 1        0.713604           1.000882           2.004326        3.890533
# 2        0.664294           0.993676           2.059116        3.447600
# 3        0.568151           0.960294           1.989442        2.871136
# 4        0.583586           0.858971           2.000512        3.771955
# 5        0.646613           0.823676           2.000837        3.828909
# 6        0.696026           1.048529           2.419531        3.411682
# 7        0.710557           0.760147           2.405094        3.053045
# 8        0.616880           0.795735           2.430688        2.979818
# 9        0.646735           1.080735           2.418656        2.874682
# 10       0.709159           1.205588           2.076710        3.320500
# 11       0.724480           0.948971           1.915385             NaN
# ...

# %%
dfloc=pd.read_excel('data/PC_Nucleolus_and_NS.xlsx',sheet_name='Compiled_NS')
#dfloc=dfloc.fillna('')
myconstructs=dfloc.columns.tolist()

print(dfloc)
print(myconstructs)


index_sort = dfloc.median().sort_values().index
sorted_feats=index_sort.tolist()
dfloc = dfloc[index_sort]

gfpmed=np.nanmedian(dfloc['GFP_NS'].tolist())
plt.figure(figsize=(5,3))
plt.plot([-1,len(myconstructs)+1],[gfpmed,gfpmed],'--',color='#000000')
sbn.boxplot(dfloc,palette='Greens')
sbn.stripplot(dfloc,color='#dddddd',size=5,linewidth=1, edgecolor='black', alpha=0.75)
plt.xticks(rotation=90) 
plt.title('Proteins that House Cluster 26 IDRs')
plt.ylabel('Nuclear Speckles Partition Coefficient')

#plt.savefig('exp_localization/figures/cluster_26_nuclear_speckles_PC.pdf', transparent=True, bbox_inches = "tight")

plt.figure(figsize=(5,3))
df_melted = pd.melt(dfloc, var_name='Protein', value_name='PC')
df_melted=df_melted.dropna()
print(df_melted)
ax=sbn.boxplot(data=df_melted, x='Protein', y='PC',palette='Greens',showfliers=False)
sbn.stripplot(data=df_melted, x='Protein', y='PC',color='#dddddd',size=5,linewidth=1, edgecolor='black', alpha=0.75)
plt.plot([0,4],[gfpmed,gfpmed],'--',color='#000000')
add_stat_annotation(ax, data=df_melted, x='Protein', y='PC', \
                    box_pairs=[(('GFP_NS', 'GFP_LUC7L2_pMK227')), \
                    (('GFP_NS', 'GFP_PRPF38B_pMK238')), \
                    (('GFP_NS', 'GFP_SNRN70_Trunc_pMK239')), \
                    (('GFP_NS', 'GFP_ZRSR2_pMK240'))], \
                    test='Mann-Whitney', text_format='star', loc='inside', verbose=2)
plt.xticks(rotation=90) 
plt.title('Proteins that House Cluster 26 IDRs')
plt.ylabel('Nuclear Speckles Partition Coefficient')
#plt.savefig('../../exp_localization/figures/cluster_26_nuclear_speckles_PC_w_stats.pdf', transparent=True, bbox_inches = "tight")

from scipy.stats import mannwhitneyu
plist=['GFP_LUC7L2_pMK227','GFP_PRPF38B_pMK238','GFP_SNRN70_Trunc_pMK239','GFP_ZRSR2_pMK240']
for i in range(0,len(plist)):
    print(mannwhitneyu(dfloc['GFP_NS'].dropna(),dfloc[plist[i]].dropna()))
# Out:
#       GFP_NS  GFP_LUC7L2_pMK227  GFP_PRPF38B_pMK238  GFP_SNRN70_Trunc_pMK239  \
# 0   0.822487           5.770276            9.757462                11.019636
# 1   0.754943           6.699379           11.443846                11.068545
# 2   0.744704           6.024138           11.837154                10.686000
# 3   0.751068           5.574138           11.158923                11.904727
# 4   0.765754           6.142000           11.323692                11.330727
# 5   0.792997           6.318966           11.597538                12.016727
# 6   0.864264           6.402897           12.366231                12.074727
# 7   0.853869           6.945862           12.654154                12.618364
# 8   0.822452           5.835310           12.758692                11.188909
# 9   0.755174           6.368069            7.978538                12.171273
# 10  0.767863           5.714207            9.049231                11.916000
# ...

# %%
dfnuc=pd.read_excel('data/PC_Nucleolus_and_NS.xlsx',sheet_name='Compiled_Nucleolus')
#dfloc=dfloc.fillna('')
myconstructs=dfnuc.columns.tolist()

print(dfnuc)
print(myconstructs)

dfnuc_GPATCH=dfnuc.drop(columns=['GFP_NKAPD1_pMK223', 'GFP_RP9_pMK224', 'GFP_BRD7_pMK229', 'GFP_FCF1_pMK230'])
print(dfnuc_GPATCH)

index_sort = dfnuc_GPATCH.median().sort_values().index
sorted_feats=index_sort.tolist()
dfnuc_GPATCH = dfnuc_GPATCH[index_sort]

gfpmed=np.nanmedian(dfnuc_GPATCH['GFP_Nucleolus'].tolist())
plt.figure(figsize=(3,3))
plt.plot([-1,len(myconstructs)+1],[gfpmed,gfpmed],'--',color='#000000')
sbn.boxplot(dfnuc_GPATCH,palette='Greens',showfliers=False)
sbn.stripplot(dfnuc_GPATCH,color='#dddddd',size=5,linewidth=1, edgecolor='black', alpha=0.75)
plt.ylabel('Nucleolus Partition Coefficient')
plt.title('GPATCH Proteins')
plt.xticks(rotation=90) 

#plt.savefig('exp_localization/figures/GPATCH_proteins_nucleolus_PC.pdf', transparent=True, bbox_inches = "tight")
# Out:
#     GFP_Nucleolus  GFP_Gpatch_pMK226  GFP_NKAPD1_pMK223  GFP_RP9_pMK224  \
# 0        0.617920           0.843088           2.007163        3.690067
# 1        0.713604           1.000882           2.004326        3.890533
# 2        0.664294           0.993676           2.059116        3.447600
# 3        0.568151           0.960294           1.989442        2.871136
# 4        0.583586           0.858971           2.000512        3.771955
# 5        0.646613           0.823676           2.000837        3.828909
# 6        0.696026           1.048529           2.419531        3.411682
# 7        0.710557           0.760147           2.405094        3.053045
# 8        0.616880           0.795735           2.430688        2.979818
# 9        0.646735           1.080735           2.418656        2.874682
# 10       0.709159           1.205588           2.076710        3.320500
# 11       0.724480           0.948971           1.915385             NaN
# ...

# %%
dfgpatchtest=pd.read_excel('data/GPatch_rnds2_and_3.xlsx',skiprows=1)
#print(dfgpatchtest)

gfpdf=pd.DataFrame()
gfpdf['GFP_Nucleolus']=dfnuc_GPATCH['GFP_Nucleolus'].tolist()

dfgpatchtest=dfgpatchtest[['GFP_Gpatch_pMK226','GFP_Swap3for4_pMK264','GFP_GPatch4_pMK232','GFP_Swap4for3_pMK265']]
dfgpatchswap=pd.concat([gfpdf,dfgpatchtest],axis=1)
print(dfgpatchswap)

mycolors=['#218342','#da4181','#f58428','#f58428','#da4181']

gfpmed=np.nanmedian(dfnuc_GPATCH['GFP_Nucleolus'].tolist())
plt.figure(figsize=(5,3))
plt.plot([-1,len(myconstructs)+1],[gfpmed,gfpmed],'--',color='#000000')
sbn.boxplot(dfgpatchswap,palette=mycolors,showfliers=False)
sbn.stripplot(dfgpatchswap,color='#dddddd',size=5,linewidth=1, edgecolor='black', alpha=0.75)
plt.ylabel('Nucleolus Partition Coefficient')
plt.title('GPATCH Proteins')
plt.xticks(rotation=90) 
#plt.ylim([0,3])
#plt.savefig('../../exp_localization/figures/GPATCH_w_swaps_proteins_nucleolus_PC.pdf', transparent=True, bbox_inches = "tight")


plt.figure(figsize=(5,3))
df_melted = pd.melt(dfgpatchswap, var_name='Protein', value_name='PC')
df_melted=df_melted.dropna()
print(df_melted)
ax=sbn.boxplot(data=df_melted, x='Protein', y='PC',palette=mycolors,showfliers=False)
sbn.stripplot(data=df_melted, x='Protein', y='PC',color='#dddddd',size=5,linewidth=1, edgecolor='black', alpha=0.75)
plt.plot([0,4],[gfpmed,gfpmed],'--',color='#000000')
add_stat_annotation(ax, data=df_melted, x='Protein', y='PC', \
                    box_pairs=[(('GFP_Nucleolus', 'GFP_Gpatch_pMK226')), \
                    (('GFP_Nucleolus', 'GFP_Swap3for4_pMK264')), \
                    (('GFP_Nucleolus', 'GFP_GPatch4_pMK232')), \
                    (('GFP_Nucleolus', 'GFP_Swap4for3_pMK265')), \
                    (('GFP_Gpatch_pMK226', 'GFP_Swap3for4_pMK264')), \
                    (('GFP_GPatch4_pMK232', 'GFP_Swap4for3_pMK265'))], \
                    test='Mann-Whitney', text_format='star', loc='inside', verbose=2)
plt.ylabel('Nucleolus Partition Coefficient')
plt.title('GPATCH Proteins')
plt.xticks(rotation=90) 
#plt.savefig('../../exp_localization/figures/GPATCH_w_swaps_proteins_nucleolus_PC_w_stats.pdf', transparent=True, bbox_inches = "tight")

from scipy.stats import mannwhitneyu
plist=['GFP_Gpatch_pMK226','GFP_Swap3for4_pMK264','GFP_GPatch4_pMK232','GFP_Swap4for3_pMK265']
for i in range(0,len(plist)):
    print(mannwhitneyu(dfnuc_GPATCH['GFP_Nucleolus'].dropna(),dfgpatchswap[plist[i]].dropna()))

print(mannwhitneyu(dfgpatchswap['GFP_Gpatch_pMK226'].dropna(),dfgpatchswap['GFP_Swap3for4_pMK264'].dropna()))
print(mannwhitneyu(dfgpatchswap['GFP_GPatch4_pMK232'].dropna(),dfgpatchswap['GFP_Swap4for3_pMK265'].dropna()))
# Out:
#     GFP_Nucleolus  GFP_Gpatch_pMK226  GFP_Swap3for4_pMK264  \
# 0        0.617920           0.843088              0.910340
# 1        0.713604           1.000882              0.907319
# 2        0.664294           0.993676              0.898766
# 3        0.568151           0.960294              0.864340
# 4        0.583586           0.858971              1.003404
# 5        0.646613           0.823676              0.908511
# 6        0.696026           1.048529              0.877617
# 7        0.710557           0.760147              0.846426
# 8        0.616880           0.795735              0.912809
# 9        0.646735           1.080735              0.986170
# 10       0.709159           1.205588              0.900000
# 11       0.724480           0.948971              0.912936
# 12       0.600628           0.990735              0.900851
# 13       0.532097           1.146618              1.050255
# 14       0.521673           1.030735              1.046043
# ...

# %%
dfgpatchtest=pd.read_excel('data/GPatch_rnds2_and_3.xlsx',skiprows=1)
print(dfgpatchtest)

index_sort = dfgpatchtest.median().sort_values().index
sorted_feats=index_sort.tolist()
print(sorted_feats)
dfgpatchtest = dfgpatchtest[index_sort]

plt.figure(figsize=(5,5))
sbn.boxplot(dfgpatchtest,palette='Greens',showfliers=False)
sbn.stripplot(dfgpatchtest,color='#dddddd',size=5,linewidth=1, edgecolor='black', alpha=0.75)
plt.ylabel('Nucleolus Partition Coefficient')
plt.title('GPATCH Proteins')
plt.xticks(rotation=90) 
#plt.ylim([0,3])
# Out:
#     GFP_Gpatch_pMK226  GFP_GPatch4_pMK232  GFP_Swap3for4_pMK264  \
# 0            0.843088           11.264471              0.910340
# 1            1.000882           14.032706              0.907319
# 2            0.993676           13.205647              0.898766
# 3            0.960294           11.978706              0.864340
# 4            0.858971           14.336824              1.003404
# 5            0.823676           14.811412              0.908511
# 6            1.048529           13.588941              0.877617
# 7            0.760147           12.065647              0.846426
# 8            0.795735            9.774235              0.912809
# 9            1.080735           10.112353              0.986170
# 10           1.205588           10.797647              0.900000
# 11           0.948971           12.045765              0.912936
# 12           0.990735            9.534824              0.900851
# 13           1.146618           11.890706              1.050255
# ...
